# %% [markdown]
# ### To gather statistics of Corpus

# %%
import numpy as np
import textstat
import pandas as pd
textstat.set_lang("en")

# %% [markdown]
# ### Gather data

# %%
original = (pd.read_table('/home/c23068554/final_project/datasets/simpa/ss.original', header=None)).tolist()
simplified = pd.read_table('/home/c23068554/final_project/datasets/simpa/ss.simplified', header=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_785647/4247469779.py in ?()
# ----> 1 original = pd.read_table('/home/c23068554/final_project/datasets/simpa/ss.original', header=None).tolist()
#       2 simplified = pd.read_table('/home/c23068554/final_project/datasets/simpa/ss.simplified', header=None)
#
# ~/miniconda3/envs/venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
print(original)
# Out:
#                                                       0
# 0     In general they are sited in areas where we th...
# 1     If required, the developer has to compile an E...
# 2     However, it is for us to decide on the Members...
# 3     In our duty to periodically review historic ar...
# 4     We also have a ‘ Housing Market Renewal Develo...
# ...                                                 ...
# 1095  New development, including extensions to build...
# 1096  Better Bus Area funding from the Department fo...
# 1097  Sheffield Care Sector Assessment Centre is app...
# 1098  They can also take part in the Sheffield Child...
# 1099  Dust can be fine particles of dry matter gener...
#
# [1100 rows x 1 columns]
